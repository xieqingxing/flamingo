# %%
import pandas as pd
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# animal      10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.iloc[:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.loc[:,['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[df.index[[3,4,6]],['animal','age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# g  snake  4.5

# %%
df[df['age'] > 1]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df.loc['f','age'] = 2.0

# %%
df['visits'].sum()
# Out:
# 19

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df[:2]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes

# %%
df.sort_values(by=['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %%
df['priority'] = df['priority'].map({'yes':True,'no':False})

# %%
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %%
df['animal'] =  df['animal'].replace('snake','python')
df.loc[:,'animal']
# Out:
# a       cat
# b       cat
# c    python
# d       dog
# e       dog
# f       cat
# g    python
# h       cat
# i       dog
# j       dog
# Name: animal, dtype: object

# %%
df.pivot_table(index='animal',columns='visits',values='age',aggfunc='mean')
# Out:
# visits    1    2    3
# animal
# cat     2.5  NaN  2.5
# dog     3.0  6.0  NaN
# python  4.5  0.5  NaN

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df1 = df.drop_duplicates(subset='A')
df1
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %%
df = pd.DataFrame(np.random.random(size=(5,3)))
df
# Out:
#           0         1         2
# 0  0.620117  0.918808  0.969439
# 1  0.483521  0.751745  0.319715
# 2  0.289537  0.307948  0.237986
# 3  0.797509  0.070733  0.172081
# 4  0.637877  0.876511  0.222292

# %%
df1 = df.sub(df.mean(axis=1), axis=0)
df1
# Out:
#           0         1         2
# 0 -0.216004  0.082687  0.133317
# 1 -0.034806  0.233418 -0.198612
# 2  0.011047  0.029458 -0.040504
# 3  0.450735 -0.276042 -0.174693
# 4  0.058983  0.297618 -0.356601

# %%
df = pd.DataFrame(np.random.random(size=(5,5)),columns=list('abcde'))
df
# Out:
#           a         b         c         d         e
# 0  0.296066  0.033661  0.757844  0.276614  0.517865
# 1  0.283729  0.244420  0.277518  0.520814  0.860975
# 2  0.997119  0.224335  0.357949  0.240233  0.760185
# 3  0.829325  0.607869  0.918166  0.388127  0.879369
# 4  0.316592  0.658478  0.543547  0.600052  0.249721

# %%
df.sum().idxmin()
# Out:
# 'b'

# %%
df = pd.DataFrame({'A': list('aaabbcaabcccbbc'), 
                   'B': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
df
# Out:
#     A    B
# 0   a   12
# 1   a  345
# 2   a    3
# 3   b    1
# 4   b   45
# 5   c   14
# 6   a    4
# 7   a   52
# 8   b   54
# 9   c   23
# 10  c  235
# 11  c   21
# 12  b   57
# 13  b    3
# 14  c   87

# %%
df1 = df.groupby('A')['B'].nlargest(3).sum(level=0)
df1
# Out:
# A
# a    409
# b    156
# c    345
# Name: B, dtype: int64

# %%
df = pd.DataFrame({'A': [1,2,11,11,33,34,35,40,79,99], 
                   'B': [1,2,11,11,33,34,35,40,79,99]})
df
# Out:
#     A   B
# 0   1   1
# 1   2   2
# 2  11  11
# 3  11  11
# 4  33  33
# 5  34  34
# 6  35  35
# 7  40  40
# 8  79  79
# 9  99  99

# %%
len(df)
# Out:
# 10

# %%
df1 = df.groupby(pd.cut(df['A'],np.arange(0,101,10)))['B'].mean()
df1
# Out:
# A
# (0, 10]       1.5
# (10, 20]     11.0
# (20, 30]      NaN
# (30, 40]     35.5
# (40, 50]      NaN
# (50, 60]      NaN
# (60, 70]      NaN
# (70, 80]     79.0
# (80, 90]      NaN
# (90, 100]    99.0
# Name: B, dtype: float64

# %%
df1[:1]
# Out:
# A
# (0, 10]    1.5
# Name: B, dtype: float64

# %%
df1.to_frame()
df1
# Out:
# A
# (0, 10]       1.5
# (10, 20]     11.0
# (20, 30]      NaN
# (30, 40]     35.5
# (40, 50]      NaN
# (50, 60]      NaN
# (60, 70]      NaN
# (70, 80]     79.0
# (80, 90]      NaN
# (90, 100]    99.0
# Name: B, dtype: float64

# %%
df = pd.DataFrame({'group': list('aabbabbbabab'),
                    'value': [1, 2, 3, np.nan, 2, 3, np.nan, 1, 7, 3, np.nan, 8]})
df
# Out:
#    group  value
# 0      a    1.0
# 1      a    2.0
# 2      b    3.0
# 3      b    NaN
# 4      a    2.0
# 5      b    3.0
# 6      b    NaN
# 7      b    1.0
# 8      a    7.0
# 9      b    3.0
# 10     a    NaN
# 11     b    8.0

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
# 插值填充
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
temp = df.From_To.str.split('_',expand=True)
temp
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
temp = df.From_To.str.split('_', expand=True)
temp.columns = ['From', 'To']
df = df.join(temp)
df = df.drop('From_To', axis=1)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    LoNDon      paris
# 1         10055            []    <Air France> (12)    MAdrid      miLAN
# 2         10065  [24, 43, 87]  (British Airways. )    londON  StockhOlm
# 3         10075          [13]       12. Air France  Budapest      PaRis
# 4         10085      [67, 32]          "Swiss Air"  Brussels     londOn

# %%
df['From'] = df.From.str.capitalize()
df['To'] = df.To.str.capitalize()
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['Airline'] = df['Airline'].str.extract('([a-zA-Z\s]+)', expand=False).str.strip()

# %%
df
# Out:
#    FlightNumber  RecentDelays          Airline      From         To
# 0         10045      [23, 47]              KLM    London      Paris
# 1         10055            []       Air France    Madrid      Milan
# 2         10065  [24, 43, 87]  British Airways    London  Stockholm
# 3         10075          [13]       Air France  Budapest      Paris
# 4         10085      [67, 32]        Swiss Air  Brussels     London

# %%
delays = df['RecentDelays'].apply(pd.Series)
delays.columns = ['delay_{}'.format(n) for n in range(1, len(delays.columns)+1)]
df = df.drop('RecentDelays', axis=1).join(delays)

df
# Out:
#    FlightNumber          Airline      From         To  delay_1  delay_2  \
# 0         10045              KLM    London      Paris     23.0     47.0
# 1         10055       Air France    Madrid      Milan      NaN      NaN
# 2         10065  British Airways    London  Stockholm     24.0     43.0
# 3         10075       Air France  Budapest      Paris     13.0      NaN
# 4         10085        Swiss Air  Brussels     London     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %%
import matplotlib.pyplot as plt
